# %% [markdown]
# ## Kutatási kérdés és módszertan

# %% [markdown]
# Az ember által létrehozott társadalmakban a családok többnyire házasság útján jönnek létre. A társadalmi szerveződések (családok, klánok, nemzetek) univerzálisak, azonban ezek a társadalmi szerveződések, így a családok létrejöttéhez kötődő szokások is kultúrspecifikusak. A házassági szokások is kulturális sokszínűséget mutatnak (Hendry, 1999). A házassági szokások számos jellemző jegy mentén mutatnak különbségeket. Részletesen kutatott téma többek között a rokonok közötti házasság tabusításának kérdése (Fox, 1983; Parker, 1996) és a monogámia-poligámia elkülönülése (Ophir&Solomon, 2020). Azt, hogy milyen házassági szokások alakulnak ki, számos tényezőre vezetik vissza a kutatók, mint például a gazdasági előnyszerzés (Itao&Kaneko, 2020). Érdekes felvetés, hogy vajon ilyen tényező-e az éghajlat. Ezek alapján a kutatási kérdésem a következő: Eltérőek-e az eltérő éghajlaton élő emberek házassággal kapcsolatos szokásai? A kérdést úgy igyekszem megválaszolni, hogy klaszterelemzést végzek és megnézem, hogy a házassághoz kapcsolódó változók (pl. monogámia vagy poligámia jellemző az adott kultúrára; jellemző-e a házasság során a hozományadás stb.) mentén milyen klaszterek rajzolódnak ki. Majd azt vizsgálom, hogy a klaszterek az éghaklathoz köthető változók (pl. átlaghőmérséklet) is különböznek-e.

# %%
import pandas as pd

# %% [markdown]
# ## 1. lépés Adatok beolvasása, adattáblá(k)ba rendezése, a szükséges oszlopok kiválasztása

# %% [markdown]
# Az elemzéshez két nagy adatbázist használtam forrásul: az Etnográfiai Atlaszt (Murdock et al., 1999) és az ecoClimate adatbázist (Lima-Ribeiro et al., 2015).

# %%
data_path = "../data/raw/EA/data.csv"
codes_path = "../data/raw/EA/codes.csv"
societies_path = "../data/raw/EA/societies.csv"
societies_mapping_path = "../data/raw/EA/societies_mapping.csv"
variables_path = "../data/raw/EA/variables.csv"
climate_path = "../data/raw/ecoClimate/data.csv"

# %% [markdown]
# ### 1.1 Az éghajlatra vonatkozó adat előkészítése

# %% [markdown]
# Beolvassuk az éghajlat adatot Pandas dataframe-ként. Megismerkedünk az adattal: lekérjük a head-et és a shape-t, hogy meglássuk mekkora az adattábla és milyen oszlopokat tartalmaz.

# %%
climate_data = pd.read_csv(climate_path)
climate_data.head()
# Out:
#   soc_id  sub_case  year                    var_id          code  comment  \
# 0  SCCS1       NaN   NaN  MonthlyMeanPrecipitation   17684.07470      NaN
# 1  SCCS2       NaN   NaN  MonthlyMeanPrecipitation   89005.31128      NaN
# 2  SCCS3       NaN   NaN  MonthlyMeanPrecipitation  134197.58310      NaN
# 3  SCCS4       NaN   NaN  MonthlyMeanPrecipitation  105957.49020      NaN
# 4  SCCS5       NaN   NaN  MonthlyMeanPrecipitation  122664.12910      NaN
#
#    references  source_coded_data  admin_comment
# 0         NaN                NaN            NaN
# 1         NaN                NaN            NaN
# 2         NaN                NaN            NaN
# 3         NaN                NaN            NaN
# 4         NaN                NaN            NaN

# %%
climate_data.shape
# Out:
# (19880, 9)

# %% [markdown]
# Az éghajlat adattáblából nekünk nincs szükségünk az összes oszlopra. Kiválasztjuk azokat, amelyekre szükségünk van: a kultúrák azonosítója (soc_id), a változók azonosítója (var_id) és a változók értékei (code). Ezekkel az oszlopokkal egy új adattáblát készítünk (climate).

# %%
climate = climate_data[["soc_id", "var_id", "code"]].copy()
climate.head()
# Out:
#   soc_id                    var_id          code
# 0  SCCS1  MonthlyMeanPrecipitation   17684.07470
# 1  SCCS2  MonthlyMeanPrecipitation   89005.31128
# 2  SCCS3  MonthlyMeanPrecipitation  134197.58310
# 3  SCCS4  MonthlyMeanPrecipitation  105957.49020
# 4  SCCS5  MonthlyMeanPrecipitation  122664.12910

# %%
climate.shape
# Out:
# (19880, 3)

# %% [markdown]
# A climate adattábla adataiból egy új adattáblát hozunk létre a következő módon. A változókat (átlagcsapadék, átlaghőmérséklet) megtesszük oszlopoknak, amelyeket feltölrünk az értékeikkel (code), indexbe tesszük a kultúrákat.

# %%
df_climate = climate.pivot(columns="var_id", values="code", index=["soc_id"])
df_climate.head()
df_climate
# Out:
# var_id  AnnualMeanTemperature  AnnualPrecipitationVariance  \
# soc_id
# Aa1                 21.035150                 1.160174e+10
# Aa2                 19.014197                 3.357365e+09
# Aa3                 20.435855                 2.158663e+09
# Aa4                 22.663076                 3.648138e+09
# Aa5                 21.417800                 9.483286e+09
# ...                       ...                          ...
# ec17                -5.450823                 3.253074e+09
# ec18                -2.851321                 3.813546e+09
# ec19                -5.380601                 7.451844e+08
# ec20                -2.562209                 2.225375e+09
# ec21                 0.277397                 3.073163e+09
#
# var_id  AnnualTemperatureVariance  MonthlyMeanPrecipitation  \
# soc_id
# Aa1                     14.598620               87000.00141
# Aa2                      1.212090               50566.30196
# Aa3                     20.629575               39669.85532
# Aa4                      8.882310               42805.12609
# Aa5                      0.305852              243307.94900
# ...                           ...                       ...
# ec17                   293.606845               67277.51153
# ec18                   277.559417               73669.72815
# ec19                   136.906919               45846.32194
# ec20                   271.300145               62833.40550
# ec21                   253.015524               73980.19285
#
# var_id  PrecipitationConstancy  PrecipitationContingency  \
# soc_id
# Aa1                   0.202518                  0.275561
# Aa2                   0.439799                  0.147196
# Aa3                   0.304052                  0.159731
# Aa4                   0.194716                  0.207159
# Aa5                   0.673789                  0.114119
# ...                        ...                       ...
# ec17                  0.469766                  0.237031
# ec18                  0.465440                  0.209449
# ec19                  0.566427                  0.064931
# ec20                  0.484034                  0.170986
# ec21                  0.516527                  0.182057
#
# var_id  PrecipitationPredictability  TemperatureConstancy  \
# soc_id
# Aa1                        0.478079              0.457627
# Aa2                        0.586995              0.667196
# Aa3                        0.463784              0.427581
# Aa4                        0.401874              0.493361
# Aa5                        0.787908              0.769289
# ...                             ...                   ...
# ec17                       0.706797              0.189064
# ec18                       0.674889              0.198889
# ec19                       0.631359              0.246243
# ec20                       0.655020              0.193270
# ec21                       0.698584              0.212138
#
# var_id  TemperatureContingency  TemperaturePredictability
# soc_id
# Aa1                   0.206115                   0.663742
# Aa2                   0.093770                   0.760966
# Aa3                   0.215104                   0.642685
# Aa4                   0.152030                   0.645391
# Aa5                   0.044588                   0.813878
# ...                        ...                        ...
# ec17                  0.360252                   0.549316
# ec18                  0.362224                   0.561113
# ec19                  0.322093                   0.568336
# ec20                  0.353516                   0.546786
# ec21                  0.364618                   0.576755
#
# [1988 rows x 10 columns]

# %% [markdown]
# Az éghajlatra vonatkozó változók közül nincs szükségünk az összesre, most csak az éves átlaghőmérsékletet és a havi átlag csapadékot fogjuk használni. Természetesen használhatnánk a többi éghajlati változót is, ami komplexebb elemzést eredményezne.

# %%
df_climate_filtered = df_climate[["AnnualMeanTemperature", "MonthlyMeanPrecipitation"]].copy()
df_climate_filtered.head()
# Out:
# var_id  AnnualMeanTemperature  MonthlyMeanPrecipitation
# soc_id
# Aa1                 21.035150               87000.00141
# Aa2                 19.014197               50566.30196
# Aa3                 20.435855               39669.85532
# Aa4                 22.663076               42805.12609
# Aa5                 21.417800              243307.94900

# %%
climate_final = df_climate_filtered.reset_index()
climate_final.head()
# Out:
# var_id soc_id  AnnualMeanTemperature  MonthlyMeanPrecipitation
# 0         Aa1              21.035150               87000.00141
# 1         Aa2              19.014197               50566.30196
# 2         Aa3              20.435855               39669.85532
# 3         Aa4              22.663076               42805.12609
# 4         Aa5              21.417800              243307.94900

# %% [markdown]
# ### 1.2 A házassági szokásokra vonatkozó adat előkészítése

# %% [markdown]
# Beolvassuk a házassági és sok más kulturális szokásokat tartalmazó adatot Pandas dataframe-ként. Megismerkedünk az adattal: lekérjük a head-et és a shape-t, hogy meglássuk mekkora az adattábla és milyen oszlopokat tartalmaz.

# %%
data = pd.read_csv(data_path)
data.head()
# Out:
#   soc_id                                  sub_case    year var_id  code  \
# 0    Aa1                          Nyai Nyae region  1950.0  EA001   8.0
# 1    Aa2  with special reference to Central Dorobo  1920.0  EA001   4.0
# 2    Aa3                          Gei/Khauan tribe  1840.0  EA001   1.0
# 3    Aa4                                       NaN  1920.0  EA001   4.0
# 4    Aa5           Epulu net-hunters, Ituri forest  1930.0  EA001   3.0
#
#   comment                                         references  \
# 0     NaN  biesele1972; biesele1975; biesele1976; draper1...
# 1     NaN  huntingford1929; huntingford1942; huntingford1...
# 2     NaN  hoernl1918; hoernl1925; kohler1970; murdock193...
# 3     NaN             lebzelter1934; schmidt1930; vedder1923
# 4     NaN  deleeuwe1966; hart1978; putnam1948; turnbull19...
#
#              source_coded_data admin_comment
# 0   EthnographicAtlas_1967_p62           NaN
# 1   EthnographicAtlas_1967_p62           NaN
# 2   EthnographicAtlas_1967_p62           NaN
# 3  Ethnology_Vol1_No3_Jul_1962           NaN
# 4   EthnographicAtlas_1967_p62           NaN

# %% [markdown]
# Egy új adattáblába átmásoljuk a számunkra releváns oszlopokat. Kiválasztjuk azokat, amelyekre szükségünk van: a kultúrák azonosítója (soc_id), a változók azonosítója (var_id) és a változók értékei (code). Ezekkel az oszlopokkal egy új adattáblát készítünk (my_df_1).

# %%
my_df_1 = data[["soc_id", "var_id", "code"]].copy()
my_df_1.head()
# Out:
#   soc_id var_id  code
# 0    Aa1  EA001   8.0
# 1    Aa2  EA001   4.0
# 2    Aa3  EA001   1.0
# 3    Aa4  EA001   4.0
# 4    Aa5  EA001   3.0

# %%
my_df_1.shape
# Out:
# (121354, 3)

# %% [markdown]
# Beolvassuk a kulturákra vonatkozó adatokhoz tartozó kódolást tartalmazó adattáblát pandas dataframe-ként.

# %%
codes = pd.read_csv(codes_path)
codes.head()
# Out:
#   var_id  code                   description    name
# 0  EA001   0.0  Zero to 5 percent dependence    0-5%
# 1  EA001   1.0    6 to 15 percent dependence   6-15%
# 2  EA001   2.0   16 to 25 percent dependence  16-25%
# 3  EA001   3.0   26 to 35 percent dependence  26-35%
# 4  EA001   4.0   36 to 45 percent dependence  36-45%

# %%
codes.shape
# Out:
# (756, 4)

# %% [markdown]
# Összeillesztjük a kódokat és az adatokat tartalmazó adattáblát a változók azonosítója (var_id) és az értékek (codes) oszlopai mentén. Azért kell egyszerre a két oszlopot néznünk, mert a leírások (description) és ezek elnevezései (name) így fognak a megfelelő sorhoz kerülni. Ugyanis 1-es kódot pl. több változó is kap. Így válik egyértelművé az adattáblák összeolvasztása.

# %%
df_merge_1 = pd.merge(codes,my_df_1, on=["var_id", "code"])
df_merge_1.head()
# Out:
#   var_id  code                   description  name soc_id
# 0  EA001   0.0  Zero to 5 percent dependence  0-5%   Ab10
# 1  EA001   0.0  Zero to 5 percent dependence  0-5%   Ab12
# 2  EA001   0.0  Zero to 5 percent dependence  0-5%   Ab13
# 3  EA001   0.0  Zero to 5 percent dependence  0-5%   Ab15
# 4  EA001   0.0  Zero to 5 percent dependence  0-5%   Ab17

# %%
df_merge_1.shape
# Out:
# (120401, 5)

# %% [markdown]
# Beolvassuk a változókat tartalmazó adattáblát.

# %%
variables = pd.read_csv(variables_path)
variables.head()
# Out:
#       id              category                                  title  \
# 0  EA001  Subsistence, Economy         Subsistence economy: gathering
# 1  EA002  Subsistence, Economy           Subsistence economy: hunting
# 2  EA003  Subsistence, Economy           Subsistence economy: fishing
# 3  EA004  Subsistence, Economy  Subsistence economy: animal husbandry
# 4  EA005  Subsistence, Economy       Subsistence economy: agriculture
#
#                                           definition     type  units  \
# 0  Dependence on the gathering of wild plants and...  Ordinal    NaN
# 1  Dependence on hunting, including trapping and ...  Ordinal    NaN
# 2  Dependence on fishing, including shellfishing ...  Ordinal    NaN
# 3  Dependence on animal husbandry, relative to ot...  Ordinal    NaN
# 4  Dependence on agriculture, relative to other s...  Ordinal    NaN
#
#                              source changes notes
# 0  Murdock (1962-1971); Gray (1999)     NaN   NaN
# 1  Murdock (1962-1971); Gray (1999)     NaN   NaN
# 2  Murdock (1962-1971); Gray (1999)     NaN   NaN
# 3  Murdock (1962-1971); Gray (1999)     NaN   NaN
# 4  Murdock (1962-1971); Gray (1999)     NaN   NaN

# %%
variables.shape
# Out:
# (94, 9)

# %% [markdown]
# Kiválasztjuk a számunkra szükséges oszlopokat és egy új adattáblába másoljuk őket. Az id változót átnevezzük, mert ez a többi adattáblában a változók azonosítója (var_id).

# %%
my_df_2 = variables[["id", "category", "title", "definition"]].copy()
my_df_2.rename(columns={"id" : "var_id"}, inplace=True)
my_df_2.head()
# Out:
#   var_id              category                                  title  \
# 0  EA001  Subsistence, Economy         Subsistence economy: gathering
# 1  EA002  Subsistence, Economy           Subsistence economy: hunting
# 2  EA003  Subsistence, Economy           Subsistence economy: fishing
# 3  EA004  Subsistence, Economy  Subsistence economy: animal husbandry
# 4  EA005  Subsistence, Economy       Subsistence economy: agriculture
#
#                                           definition
# 0  Dependence on the gathering of wild plants and...
# 1  Dependence on hunting, including trapping and ...
# 2  Dependence on fishing, including shellfishing ...
# 3  Dependence on animal husbandry, relative to ot...
# 4  Dependence on agriculture, relative to other s...

# %% [markdown]
# Összeillesztjük a fentebb létrejött összeillesztett adattáblát (df_merge_1) és a változókat szövegesen felsoroló adattáblát.

# %%
df_merge_2 = pd.merge(df_merge_1,my_df_2, on=["var_id"])
df_merge_2.head()
# Out:
#   var_id  code                   description  name soc_id  \
# 0  EA001   0.0  Zero to 5 percent dependence  0-5%   Ab10
# 1  EA001   0.0  Zero to 5 percent dependence  0-5%   Ab12
# 2  EA001   0.0  Zero to 5 percent dependence  0-5%   Ab13
# 3  EA001   0.0  Zero to 5 percent dependence  0-5%   Ab15
# 4  EA001   0.0  Zero to 5 percent dependence  0-5%   Ab17
#
#                category                           title  \
# 0  Subsistence, Economy  Subsistence economy: gathering
# 1  Subsistence, Economy  Subsistence economy: gathering
# 2  Subsistence, Economy  Subsistence economy: gathering
# 3  Subsistence, Economy  Subsistence economy: gathering
# 4  Subsistence, Economy  Subsistence economy: gathering
#
#                                           definition
# 0  Dependence on the gathering of wild plants and...
# 1  Dependence on the gathering of wild plants and...
# 2  Dependence on the gathering of wild plants and...
# 3  Dependence on the gathering of wild plants and...
# 4  Dependence on the gathering of wild plants and...

# %% [markdown]
# ### 1.3 A kultúrákra/társadalmakra vonatkozó adat előkészítése

# %% [markdown]
# Beolvassuk a kultúrákra/társadalmakra adatot Pandas dataframe-ként. Megismerkedünk az adattal: lekérjük a head-et és a shape-t, hogy meglássuk mekkora az adattábla és milyen oszlopokat tartalmaz

# %%
societies = pd.read_csv(societies_path)
societies.head()
# Out:
#      id  xd_id pref_name_for_society glottocode  \
# 0   Aa1    xd1                 !Kung   juho1239
# 1   Ab1   xd10                Herero   here1253
# 2  Ad31  xd100                Duruma   duru1249
# 3  Ad32  xd101               Giriama   giry1241
# 4  Ad33  xd102                Pokomo   poko1261
#
#   ORIG_name_and_ID_in_this_dataset                      alt_names_by_society  \
# 0                       Kung (Aa1)  Kung Bushmen, !Kung (Was Nyae), Was Nyae
# 1                     Herero (Ab1)                         Damara, Ovaherero
# 2                    Duruma (Ad31)                                  Waduruma
# 3                   Giriama (Ad32)                        Kiriama, Wagiryama
# 4                    Pokomo (Ad33)                                  Wapokomo
#
#    main_focal_year HRAF_name_ID  \
# 0           1950.0   San (FX10)
# 1           1900.0          NaN
# 2           1910.0          NaN
# 3           1900.0          NaN
# 4           1900.0          NaN
#
#                                            HRAF_link  origLat  origLong   Lat  \
# 0  http://ehrafworldcultures.yale.edu/collection?...    -20.0      21.0 -20.0
# 1                                                NaN    -21.0      16.0 -21.0
# 2                                                NaN     -4.0      39.0  -4.0
# 3                                                NaN     -3.0      40.0  -3.0
# 4                                                NaN     -1.0      40.0  -1.0
#
#    Long   Comment glottocode_comment
# 0  21.0  Original                NaN
# 1  16.0  Original                NaN
# 2  39.0  Original                NaN
# 3  40.0  Original                NaN
# 4  40.0  Original                NaN

# %%
societies.shape
# Out:
# (1291, 15)

# %% [markdown]
# Kiválasztjuk a számunkra releváns oszlopokat: a kultúra azonosítóját (id), amelyet átnevezünk soc_id-ra, a kultúra nevét, a hosszúsági és szélellési adatot. Új adattáblát készítünk ezekből.

# %%
my_df_3 = societies[["id", "pref_name_for_society", "Lat", "Long"]].copy()
my_df_3.rename(columns={"id" : "soc_id"}, inplace=True)
my_df_3.head()
# Out:
#   soc_id pref_name_for_society   Lat  Long
# 0    Aa1                 !Kung -20.0  21.0
# 1    Ab1                Herero -21.0  16.0
# 2   Ad31                Duruma  -4.0  39.0
# 3   Ad32               Giriama  -3.0  40.0
# 4   Ad33                Pokomo  -1.0  40.0

# %% [markdown]
# Az összegyúrt adattáblához (df_merge_2) ezt is hozzágyúrjuk a kultúra azonosítója (soc_id) mentén.

# %%
df_merge_3 = pd.merge(df_merge_2,my_df_3,on=["soc_id"])
df_merge_3.head()
# Out:
#   var_id  code                   description  name soc_id  \
# 0  EA001   0.0  Zero to 5 percent dependence  0-5%   Ab10
# 1  EA001   0.0  Zero to 5 percent dependence  0-5%   Ab12
# 2  EA001   0.0  Zero to 5 percent dependence  0-5%   Ab13
# 3  EA001   0.0  Zero to 5 percent dependence  0-5%   Ab15
# 4  EA001   0.0  Zero to 5 percent dependence  0-5%   Ab17
#
#                category                           title  \
# 0  Subsistence, Economy  Subsistence economy: gathering
# 1  Subsistence, Economy  Subsistence economy: gathering
# 2  Subsistence, Economy  Subsistence economy: gathering
# 3  Subsistence, Economy  Subsistence economy: gathering
# 4  Subsistence, Economy  Subsistence economy: gathering
#
#                                           definition pref_name_for_society  \
# 0  Dependence on the gathering of wild plants and...           Pondo Xhosa
# 1  Dependence on the gathering of wild plants and...                  Zulu
# 2  Dependence on the gathering of wild plants and...                Tswana
# 3  Dependence on the gathering of wild plants and...                  Pedi
# 4  Dependence on the gathering of wild plants and...                  Ndau
#
#     Lat  Long
# 0 -31.0  30.0
# 1 -29.0  31.0
# 2 -24.0  27.0
# 3 -25.0  30.0
# 4 -20.0  34.0

# %%
df_merge_3.shape
# Out:
# (120401, 11)

# %% [markdown]
# Beolvassuk a kulturákkal kapcsolatos plusz információkat tartalmazó adattáblát. Tanulmányozzuk az oszlopokat, majd megállapítjuk, hogy ezt az adattáblát nem használjuk a későbbiekben, mert nem tartalmaz számunkra releváns adatot.

# %%
societies_mapping = pd.read_csv(societies_mapping_path)
societies_mapping.head()
# Out:
#      id                                   related
# 0   Aa1  Binford: !Kung [B72]; SCCS: Kung [SCCS2]
# 1   Ab1                                       NaN
# 2  Ad31                                       NaN
# 3  Ad32                                       NaN
# 4  Ad33                                       NaN

# %% [markdown]
# ## 2. Adattisztítás, adatrendezés

# %% [markdown]
# Megnézzük, hogy a minden szükséges adatot tartalmazó giga adattáblánk milyen oszlopokat tartalmaz.

# %%
for col in df_merge_3.columns:
    print(col)
# Out:
# var_id
# code
# description
# name
# soc_id
# category
# title
# definition
# pref_name_for_society
# Lat
# Long

# %% [markdown]
# Mivel mi a házassági szokásokat kívánjuk vizsgálni, ezért a változók közül kiszűrjük azokat a kategóriákat, amelyekben szerepel a "marriage" szó. Megnézzük, mik ezek a kategóriák.

# %%
marriage = list(df_merge_3["category"])
m = [True if "marriage" in e.lower() else False for e in marriage]
df_merge_3["m?"] = m

# %%
df_marriage = df_merge_3[df_merge_3["m?"] == True]

# %%
set(df_marriage["category"])
# Out:
# {'Marriage, Kinship',
#  'Marriage, Kinship, Community organization',
#  'Marriage, Kinship, Wealth Transactions, Economy',
#  'Ritual, Gender, Marriage'}

# %%
df_marriage.shape
# Out:
# (24529, 12)

# %% [markdown]
# Kidobjuk azokat a sorokat, ahol a házasság szót tartalmazó kategóriához nem tartozik érték, ugyanis ezekkel nem tudunk/akarunk dolgozni.

# %%
df_no_na = df_marriage.dropna(subset=["code"])
df_no_na
# Out:
#        var_id  code                                        description  \
# 6474    EA006   1.0  Bride-price or bride-wealth, i.e., transfer of...
# 6475    EA006   1.0  Bride-price or bride-wealth, i.e., transfer of...
# 6476    EA006   1.0  Bride-price or bride-wealth, i.e., transfer of...
# 6477    EA006   1.0  Bride-price or bride-wealth, i.e., transfer of...
# 6478    EA006   1.0  Bride-price or bride-wealth, i.e., transfer of...
# ...       ...   ...                                                ...
# 101984  EA078   6.0  Premarital sex relations freely permitted and ...
# 101985  EA078   6.0  Premarital sex relations freely permitted and ...
# 101986  EA078   6.0  Premarital sex relations freely permitted and ...
# 101987  EA078   6.0  Premarital sex relations freely permitted and ...
# 101988  EA078   6.0  Premarital sex relations freely permitted and ...
#
#                            name soc_id  \
# 6474               Bride-wealth    Aa2
# 6475               Bride-wealth    Aa6
# 6476               Bride-wealth    Aa9
# 6477               Bride-wealth    Ab1
# 6478               Bride-wealth   Ab10
# ...                         ...    ...
# 101984  Permitted, no sanctions   ec12
# 101985  Permitted, no sanctions   ec13
# 101986  Permitted, no sanctions   ec14
# 101987  Permitted, no sanctions   ec16
# 101988  Permitted, no sanctions   ec20
#
#                                                category  \
# 6474    Marriage, Kinship, Wealth Transactions, Economy
# 6475    Marriage, Kinship, Wealth Transactions, Economy
# 6476    Marriage, Kinship, Wealth Transactions, Economy
# 6477    Marriage, Kinship, Wealth Transactions, Economy
# 6478    Marriage, Kinship, Wealth Transactions, Economy
# ...                                                 ...
# 101984                         Ritual, Gender, Marriage
# 101985                         Ritual, Gender, Marriage
# 101986                         Ritual, Gender, Marriage
# 101987                         Ritual, Gender, Marriage
# 101988                         Ritual, Gender, Marriage
#
#                                                title  \
# 6474       Transactions at marriage: prevailing type
# 6475       Transactions at marriage: prevailing type
# 6476       Transactions at marriage: prevailing type
# 6477       Transactions at marriage: prevailing type
# 6478       Transactions at marriage: prevailing type
# ...                                              ...
# 101984  Norms of premarital sexual behavior of girls
# 101985  Norms of premarital sexual behavior of girls
# 101986  Norms of premarital sexual behavior of girls
# 101987  Norms of premarital sexual behavior of girls
# 101988  Norms of premarital sexual behavior of girls
#
#                                                definition  \
# 6474    Prevailing type of transfer or exchange at mar...
# 6475    Prevailing type of transfer or exchange at mar...
# 6476    Prevailing type of transfer or exchange at mar...
# 6477    Prevailing type of transfer or exchange at mar...
# 6478    Prevailing type of transfer or exchange at mar...
# ...                                                   ...
# 101984  Prevailing standards of sex behavior for unmar...
# 101985  Prevailing standards of sex behavior for unmar...
# 101986  Prevailing standards of sex behavior for unmar...
# 101987  Prevailing standards of sex behavior for unmar...
# 101988  Prevailing standards of sex behavior for unmar...
#
#        pref_name_for_society    Lat    Long    m?
# 6474                  Dorobo   0.00   36.00  True
# 6475                 Sandawe  -5.00   36.00  True
# 6476                   Hadza  -3.00   35.00  True
# 6477                  Herero -21.00   16.00  True
# 6478             Pondo Xhosa -31.00   30.00  True
# ...                      ...    ...     ...   ...
# 101984              Nganasan  72.00   90.00  True
# 101985               Itelmen  54.98  161.79  True
# 101986            Ungazikmit  64.00 -173.00  True
# 101987                 Evenk  55.00  112.00  True
# 101988                 Oroch  51.00  138.00  True
#
# [20761 rows x 12 columns]

# %%
df_no_na.shape
# Out:
# (20761, 12)

# %% [markdown]
# A házassággal kapcsolatos változó példányait (pl. community marriage organization) megtesszük egy új adattábla oszlopainak.A szélességi és hosszúsági adatokat, a kultúra azonosítóját a nevét megtesszük indexnek.

# %%
df_by_cultures=df_no_na.pivot(columns="title", values="name", index = ["Lat", "Long","pref_name_for_society", "soc_id"])
df_by_cultures
# Out:
# title                                               Community marriage organization  \
# Lat    Long    pref_name_for_society         soc_id
# -55.02 -68.98  Yahgan                        Sg1                          Exogamous
# -54.00 -69.00  Ona                           Sg3                          Exogamous
# -52.00 -74.00  Alacaluf                      Sg5                            Agamous
# -46.00 -70.00  Tehuelche                     Sg4                            Agamous
# -42.00  146.00 Tasmanians (northwestern)     Id8                          Exogamous
# ...                                                                             ...
#  70.00 -82.00  Iglulik Inuit                 Na22                         Exogamous
#         145.00 Yukaghir                      Ec6                          Exogamous
#  71.00 -157.00 Tareumiut                     Na2                            Agamous
#  72.00  90.00  Nganasan                      ec12                             Demes
#  78.00 -70.00  Inughuit (Northern Greenland) Na14                           Agamous
#
# title                                               Cousin marriages permitted  \
# Lat    Long    pref_name_for_society         soc_id
# -55.02 -68.98  Yahgan                        Sg1       No first/second cousins
# -54.00 -69.00  Ona                           Sg3       No first/second cousins
# -52.00 -74.00  Alacaluf                      Sg5             Any first cousins
# -46.00 -70.00  Tehuelche                     Sg4             Any first cousins
# -42.00  146.00 Tasmanians (northwestern)     Id8                           NaN
# ...                                                                        ...
#  70.00 -82.00  Iglulik Inuit                 Na22      No first/second cousins
#         145.00 Yukaghir                      Ec6           Only second cousins
#  71.00 -157.00 Tareumiut                     Na2       No first/second cousins
#  72.00  90.00  Nganasan                      ec12      No first/second cousins
#  78.00 -70.00  Inughuit (Northern Greenland) Na14                          NaN
#
# title                                               Cousin marriages permitted: subtypes  \
# Lat    Long    pref_name_for_society         soc_id
# -55.02 -68.98  Yahgan                        Sg1                 No first/second cousins
# -54.00 -69.00  Ona                           Sg3                 No first/second cousins
# -52.00 -74.00  Alacaluf                      Sg5                           Quadrilateral
# -46.00 -70.00  Tehuelche                     Sg4                           Quadrilateral
# -42.00  146.00 Tasmanians (northwestern)     Id8                                     NaN
# ...                                                                                  ...
#  70.00 -82.00  Iglulik Inuit                 Na22                No first/second cousins
#         145.00 Yukaghir                      Ec6                     Only second cousins
#  71.00 -157.00 Tareumiut                     Na2                 No first/second cousins
#  72.00  90.00  Nganasan                      ec12                No first/second cousins
#  78.00 -70.00  Inughuit (Northern Greenland) Na14                                    NaN
#
# title                                               Cousin marriages preferred  \
# Lat    Long    pref_name_for_society         soc_id
# -55.02 -68.98  Yahgan                        Sg1                None preferred
# -54.00 -69.00  Ona                           Sg3                None preferred
# -52.00 -74.00  Alacaluf                      Sg5                None preferred
# -46.00 -70.00  Tehuelche                     Sg4                None preferred
# -42.00  146.00 Tasmanians (northwestern)     Id8                           NaN
# ...                                                                        ...
#  70.00 -82.00  Iglulik Inuit                 Na22               None preferred
#         145.00 Yukaghir                      Ec6                None preferred
#  71.00 -157.00 Tareumiut                     Na2                None preferred
#  72.00  90.00  Nganasan                      ec12               None preferred
#  78.00 -70.00  Inughuit (Northern Greenland) Na14                          NaN
#
# title                                               Cousin marriages preferred: subtypes  \
# Lat    Long    pref_name_for_society         soc_id
# -55.02 -68.98  Yahgan                        Sg1                          None preferred
# -54.00 -69.00  Ona                           Sg3                          None preferred
# -52.00 -74.00  Alacaluf                      Sg5                          None preferred
# -46.00 -70.00  Tehuelche                     Sg4                          None preferred
# -42.00  146.00 Tasmanians (northwestern)     Id8                                     NaN
# ...                                                                                  ...
#  70.00 -82.00  Iglulik Inuit                 Na22                         None preferred
#         145.00 Yukaghir                      Ec6                          None preferred
#  71.00 -157.00 Tareumiut                     Na2                          None preferred
#  72.00  90.00  Nganasan                      ec12                         None preferred
#  78.00 -70.00  Inughuit (Northern Greenland) Na14                                    NaN
#
# title                                                    Domestic organization  \
# Lat    Long    pref_name_for_society         soc_id
# -55.02 -68.98  Yahgan                        Sg1     Nuclear, limited polygyny
# -54.00 -69.00  Ona                           Sg3     Nuclear, limited polygyny
# -52.00 -74.00  Alacaluf                      Sg5     Nuclear, limited polygyny
# -46.00 -70.00  Tehuelche                     Sg4                Small extended
# -42.00  146.00 Tasmanians (northwestern)     Id8     Nuclear, limited polygyny
# ...                                                                        ...
#  70.00 -82.00  Iglulik Inuit                 Na22               Small extended
#         145.00 Yukaghir                      Ec6              Minimal extended
#  71.00 -157.00 Tareumiut                     Na2                Small extended
#  72.00  90.00  Nganasan                      ec12               Large extended
#  78.00 -70.00  Inughuit (Northern Greenland) Na14    Nuclear, limited polygyny
#
# title                                               Marital composition: monogamy and polygamy  \
# Lat    Long    pref_name_for_society         soc_id
# -55.02 -68.98  Yahgan                        Sg1                              Limited polygyny
# -54.00 -69.00  Ona                           Sg3                              Limited polygyny
# -52.00 -74.00  Alacaluf                      Sg5                              Limited polygyny
# -46.00 -70.00  Tehuelche                     Sg4                              Limited polygyny
# -42.00  146.00 Tasmanians (northwestern)     Id8                              Limited polygyny
# ...                                                                                        ...
#  70.00 -82.00  Iglulik Inuit                 Na22                             Limited polygyny
#         145.00 Yukaghir                      Ec6                              Limited polygyny
#  71.00 -157.00 Tareumiut                     Na2                 Polygyny, non-sororal cohabit
#  72.00  90.00  Nganasan                      ec12                             Limited polygyny
#  78.00 -70.00  Inughuit (Northern Greenland) Na14                             Limited polygyny
#
# title                                               Marital residence with kin: alternate  \
# Lat    Long    pref_name_for_society         soc_id
# -55.02 -68.98  Yahgan                        Sg1                             No alternate
# -54.00 -69.00  Ona                           Sg3                                 Neolocal
# -52.00 -74.00  Alacaluf                      Sg5                                 Neolocal
# -46.00 -70.00  Tehuelche                     Sg4                             No alternate
# -42.00  146.00 Tasmanians (northwestern)     Id8                                      NaN
# ...                                                                                   ...
#  70.00 -82.00  Iglulik Inuit                 Na22                              Uxorilocal
#         145.00 Yukaghir                      Ec6                                Virilocal
#  71.00 -157.00 Tareumiut                     Na2                             No alternate
#  72.00  90.00  Nganasan                      ec12                              Matrilocal
#  78.00 -70.00  Inughuit (Northern Greenland) Na14                                Neolocal
#
# title                                               Marital residence with kin: change after first years  \
# Lat    Long    pref_name_for_society         soc_id
# -55.02 -68.98  Yahgan                        Sg1                                                  Same
# -54.00 -69.00  Ona                           Sg3                                                  Same
# -52.00 -74.00  Alacaluf                      Sg5                                             Different
# -46.00 -70.00  Tehuelche                     Sg4                                                  Same
# -42.00  146.00 Tasmanians (northwestern)     Id8                                                   NaN
# ...                                                                                                ...
#  70.00 -82.00  Iglulik Inuit                 Na22                                                 Same
#         145.00 Yukaghir                      Ec6                                             Different
#  71.00 -157.00 Tareumiut                     Na2                                                  Same
#  72.00  90.00  Nganasan                      ec12                                            Different
#  78.00 -70.00  Inughuit (Northern Greenland) Na14                                                 Same
#
# title                                               Marital residence with kin: first years  \
# Lat    Long    pref_name_for_society         soc_id
# -55.02 -68.98  Yahgan                        Sg1                                  Virilocal
# -54.00 -69.00  Ona                           Sg3                                  Virilocal
# -52.00 -74.00  Alacaluf                      Sg5                                 Uxorilocal
# -46.00 -70.00  Tehuelche                     Sg4                                  Virilocal
# -42.00  146.00 Tasmanians (northwestern)     Id8                                        NaN
# ...                                                                                     ...
#  70.00 -82.00  Iglulik Inuit                 Na22                                 Ambi-viri
#         145.00 Yukaghir                      Ec6                                 Uxorilocal
#  71.00 -157.00 Tareumiut                     Na2                                  Ambilocal
#  72.00  90.00  Nganasan                      ec12                                 Virilocal
#  78.00 -70.00  Inughuit (Northern Greenland) Na14                                 Ambilocal
#
# title                                               Marital residence with kin: prevailing pattern  \
# Lat    Long    pref_name_for_society         soc_id
# -55.02 -68.98  Yahgan                        Sg1                                         Virilocal
# -54.00 -69.00  Ona                           Sg3                                         Virilocal
# -52.00 -74.00  Alacaluf                      Sg5                                         Ambilocal
# -46.00 -70.00  Tehuelche                     Sg4                                         Virilocal
# -42.00  146.00 Tasmanians (northwestern)     Id8                                               NaN
# ...                                                                                            ...
#  70.00 -82.00  Iglulik Inuit                 Na22                                        Ambi-viri
#         145.00 Yukaghir                      Ec6                                          Ambi-uxo
#  71.00 -157.00 Tareumiut                     Na2                                         Ambilocal
#  72.00  90.00  Nganasan                      ec12                                       Patrilocal
#  78.00 -70.00  Inughuit (Northern Greenland) Na14                                        Ambilocal
#
# title                                               Norms of premarital sexual behavior of girls  \
# Lat    Long    pref_name_for_society         soc_id
# -55.02 -68.98  Yahgan                        Sg1                Prohibited but weakly sanctioned
# -54.00 -69.00  Ona                           Sg3                 Prohibited, strongly sanctioned
# -52.00 -74.00  Alacaluf                      Sg5                                             NaN
# -46.00 -70.00  Tehuelche                     Sg4                Prohibited but weakly sanctioned
# -42.00  146.00 Tasmanians (northwestern)     Id8                                             NaN
# ...                                                                                          ...
#  70.00 -82.00  Iglulik Inuit                 Na22               Prohibited but weakly sanctioned
#         145.00 Yukaghir                      Ec6                                             NaN
#  71.00 -157.00 Tareumiut                     Na2                         Permitted, no sanctions
#  72.00  90.00  Nganasan                      ec12                        Permitted, no sanctions
#  78.00 -70.00  Inughuit (Northern Greenland) Na14                        Permitted, no sanctions
#
# title                                               Organization of clan communities  \
# Lat    Long    pref_name_for_society         soc_id
# -55.02 -68.98  Yahgan                        Sg1                  No exogamous clans
# -54.00 -69.00  Ona                           Sg3                  No exogamous clans
# -52.00 -74.00  Alacaluf                      Sg5                  No exogamous clans
# -46.00 -70.00  Tehuelche                     Sg4                  No exogamous clans
# -42.00  146.00 Tasmanians (northwestern)     Id8                  No exogamous clans
# ...                                                                              ...
#  70.00 -82.00  Iglulik Inuit                 Na22                 No exogamous clans
#         145.00 Yukaghir                      Ec6                  No exogamous clans
#  71.00 -157.00 Tareumiut                     Na2                  No exogamous clans
#  72.00  90.00  Nganasan                      ec12                 No exogamous clans
#  78.00 -70.00  Inughuit (Northern Greenland) Na14                 No exogamous clans
#
# title                                               Post-partum sex taboos  \
# Lat    Long    pref_name_for_society         soc_id
# -55.02 -68.98  Yahgan                        Sg1         One to six months
# -54.00 -69.00  Ona                           Sg3                       NaN
# -52.00 -74.00  Alacaluf                      Sg5           Up to one month
# -46.00 -70.00  Tehuelche                     Sg4      Six months to a year
# -42.00  146.00 Tasmanians (northwestern)     Id8       A year to two years
# ...                                                                    ...
#  70.00 -82.00  Iglulik Inuit                 Na22        One to six months
#         145.00 Yukaghir                      Ec6           Up to one month
#  71.00 -157.00 Tareumiut                     Na2                       NaN
#  72.00  90.00  Nganasan                      ec12          Up to one month
#  78.00 -70.00  Inughuit (Northern Greenland) Na14      More than two years
#
# title                                               Segregation of adolescent boys  \
# Lat    Long    pref_name_for_society         soc_id
# -55.02 -68.98  Yahgan                        Sg1                               NaN
# -54.00 -69.00  Ona                           Sg3                    No segregation
# -52.00 -74.00  Alacaluf                      Sg5                               NaN
# -46.00 -70.00  Tehuelche                     Sg4                    No segregation
# -42.00  146.00 Tasmanians (northwestern)     Id8                               NaN
# ...                                                                            ...
#  70.00 -82.00  Iglulik Inuit                 Na22                   No segregation
#         145.00 Yukaghir                      Ec6                    No segregation
#  71.00 -157.00 Tareumiut                     Na2                    No segregation
#  72.00  90.00  Nganasan                      ec12                   No segregation
#  78.00 -70.00  Inughuit (Northern Greenland) Na14                          Partial
#
# title                                               Transactions at marriage: alternate type  \
# Lat    Long    pref_name_for_society         soc_id
# -55.02 -68.98  Yahgan                        Sg1                          Token bride-wealth
# -54.00 -69.00  Ona                           Sg3                                No alternate
# -52.00 -74.00  Alacaluf                      Sg5                                No alternate
# -46.00 -70.00  Tehuelche                     Sg4                                Bride-wealth
# -42.00  146.00 Tasmanians (northwestern)     Id8                                No alternate
# ...                                                                                      ...
#  70.00 -82.00  Iglulik Inuit                 Na22                               No alternate
#         145.00 Yukaghir                      Ec6                              Woman exchange
#  71.00 -157.00 Tareumiut                     Na2                                No alternate
#  72.00  90.00  Nganasan                      ec12                             Woman exchange
#  78.00 -70.00  Inughuit (Northern Greenland) Na14                               No alternate
#
# title                                               Transactions at marriage: prevailing type  \
# Lat    Long    pref_name_for_society         soc_id
# -55.02 -68.98  Yahgan                        Sg1                                Bride-service
# -54.00 -69.00  Ona                           Sg3                                Insignificant
# -52.00 -74.00  Alacaluf                      Sg5                                Insignificant
# -46.00 -70.00  Tehuelche                     Sg4                                Gift exchange
# -42.00  146.00 Tasmanians (northwestern)     Id8                                Insignificant
# ...                                                                                       ...
#  70.00 -82.00  Iglulik Inuit                 Na22                               Insignificant
#         145.00 Yukaghir                      Ec6                                Bride-service
#  71.00 -157.00 Tareumiut                     Na2                                Insignificant
#  72.00  90.00  Nganasan                      ec12                                Bride-wealth
#  78.00 -70.00  Inughuit (Northern Greenland) Na14                               Insignificant
#
# title                                               Transfer of residence at marriage: alternate  \
# Lat    Long    pref_name_for_society         soc_id
# -55.02 -68.98  Yahgan                        Sg1                                    No alternate
# -54.00 -69.00  Ona                           Sg3                                  Ambi/neo-local
# -52.00 -74.00  Alacaluf                      Sg5                                    No alternate
# -46.00 -70.00  Tehuelche                     Sg4                                    No alternate
# -42.00  146.00 Tasmanians (northwestern)     Id8                                             NaN
# ...                                                                                          ...
#  70.00 -82.00  Iglulik Inuit                 Na22                                Husband to wife
#         145.00 Yukaghir                      Ec6                                 Wife to husband
#  71.00 -157.00 Tareumiut                     Na2                                    No alternate
#  72.00  90.00  Nganasan                      ec12                                Husband to wife
#  78.00 -70.00  Inughuit (Northern Greenland) Na14                                   No alternate
#
# title                                               Transfer of residence at marriage: prevailing pattern
# Lat    Long    pref_name_for_society         soc_id
# -55.02 -68.98  Yahgan                        Sg1                                       Wife to husband
# -54.00 -69.00  Ona                           Sg3                                       Wife to husband
# -52.00 -74.00  Alacaluf                      Sg5                                        Ambi/neo-local
# -46.00 -70.00  Tehuelche                     Sg4                                       Wife to husband
# -42.00  146.00 Tasmanians (northwestern)     Id8                                                   NaN
# ...                                                                                                ...
#  70.00 -82.00  Iglulik Inuit                 Na22                                       Ambi/neo-local
#         145.00 Yukaghir                      Ec6                                        Ambi/neo-local
#  71.00 -157.00 Tareumiut                     Na2                                        Ambi/neo-local
#  72.00  90.00  Nganasan                      ec12                                      Wife to husband
#  78.00 -70.00  Inughuit (Northern Greenland) Na14                                       Ambi/neo-local
#
# [1287 rows x 19 columns]

# %%
df_by_cultures.shape
# Out:
# (1287, 19)

# %% [markdown]
# Meg akarunk szabadulni az N/A értékektől. Ezt 2 módon tehetjük: megszabadulunk a sortól, azaz a kultúrától, vagy megszabadulunk az oszloptól, azaz a házasságra vonatkozó változótól. Először ez utóbbival kezdjük. Kidobunk minden olyan változót, amely 20%-nál több N/A-t tartalmaz. Majd kidobjuk a kultúrákat, ahol a megmaradt változó neveknél N/A van.

# %%
unnecessary_category = []
for column in df_by_cultures.columns:
    l = df_by_cultures[column]
    number_of_nans = l.isna().sum()
    percent_of_nans = number_of_nans/len(l)*100
    if percent_of_nans > 20:
        unnecessary_category.append(column)
    print(column)
    print(percent_of_nans)
print(unnecessary_category)
# Out:
# Community marriage organization
# 14.374514374514375
# Cousin marriages permitted
# 19.036519036519035
# Cousin marriages permitted: subtypes
# 19.036519036519035
# Cousin marriages preferred
# 19.036519036519035
# Cousin marriages preferred: subtypes
# 19.036519036519035
# Domestic organization
# 1.8648018648018647
# Marital composition: monogamy and polygamy
# 2.331002331002331
# Marital residence with kin: alternate
# 1.554001554001554
# Marital residence with kin: change after first years
# 1.554001554001554
# Marital residence with kin: first years
# 1.554001554001554
# Marital residence with kin: prevailing pattern
# 1.554001554001554
# Norms of premarital sexual behavior of girls
# 53.535353535353536
# Organization of clan communities
# 14.374514374514375
# Post-partum sex taboos
# 71.0955710955711
# Segregation of adolescent boys
# 41.49184149184149
# Transactions at marriage: alternate type
# 1.1655011655011656
# Transactions at marriage: prevailing type
# 1.1655011655011656
# Transfer of residence at marriage: alternate
# 1.554001554001554
# Transfer of residence at marriage: prevailing pattern
# 1.554001554001554
# ['Norms of premarital sexual behavior of girls', 'Post-partum sex taboos', 'Segregation of adolescent boys']

# %%
df_filtered = df_by_cultures.drop(columns=unnecessary_category)
df_filtered.dropna(inplace=True)
df_filtered.shape
# Out:
# (914, 16)

# %% [markdown]
# Láthatjuk, hogy az elemzésünk 914 országra fog vonatkozni, amelyeket 16 változó alapján fogunk klaszterekbe sorolni. A 16 változó a következő: Community marriage organization, Cousin marriages permitted, Cousin marriages permitted: subtypes, Cousin marriages preferred, Cousin marriages preferred: subtypes, Domestic organization, Marital composition: monogamy and polygamy, Marital residence with kin: alternate, Marital residence with kin: change after first years, Marital residence with kin: first years, Marital residence with kin: prevailing pattern, Organization of clan communities, Transactions at marriage: alternate type, Transactions at marriage: prevailing type, Transfer of residence at marriage: alternate, Transfer of residence at marriage: prevailing pattern

# %% [markdown]
# Az exploratory data analysis és a klaszterezés úgy végezhető, ha nem string értékeink, hanem numerikus értékekeink vannak, ezért átkódoljuk az értékeinket.

# %%
from sklearn.preprocessing import LabelEncoder

categorials = []
for col in df_filtered.columns:
    label_encoder = LabelEncoder()
    y = label_encoder.fit_transform(df_filtered[col])
    col_name = col + "_numeric"
    df_filtered[col_name] = y
    categorials.append(col)

# %%
df_filtered.shape
# Out:
# (914, 32)

# %%
df_filtered.head()
# Out:
# title                                      Community marriage organization  \
# Lat    Long   pref_name_for_society soc_id
# -55.02 -68.98 Yahgan                Sg1                          Exogamous
# -54.00 -69.00 Ona                   Sg3                          Exogamous
# -52.00 -74.00 Alacaluf              Sg5                            Agamous
# -46.00 -70.00 Tehuelche             Sg4                            Agamous
# -39.00 -68.00 Mapuche               Sg2                 Segmented, exogamy
#
# title                                      Cousin marriages permitted  \
# Lat    Long   pref_name_for_society soc_id
# -55.02 -68.98 Yahgan                Sg1       No first/second cousins
# -54.00 -69.00 Ona                   Sg3       No first/second cousins
# -52.00 -74.00 Alacaluf              Sg5             Any first cousins
# -46.00 -70.00 Tehuelche             Sg4             Any first cousins
# -39.00 -68.00 Mapuche               Sg2       Matrilateral cross only
#
# title                                      Cousin marriages permitted: subtypes  \
# Lat    Long   pref_name_for_society soc_id
# -55.02 -68.98 Yahgan                Sg1                 No first/second cousins
# -54.00 -69.00 Ona                   Sg3                 No first/second cousins
# -52.00 -74.00 Alacaluf              Sg5                           Quadrilateral
# -46.00 -70.00 Tehuelche             Sg4                           Quadrilateral
# -39.00 -68.00 Mapuche               Sg2                              Unilateral
#
# title                                      Cousin marriages preferred  \
# Lat    Long   pref_name_for_society soc_id
# -55.02 -68.98 Yahgan                Sg1                None preferred
# -54.00 -69.00 Ona                   Sg3                None preferred
# -52.00 -74.00 Alacaluf              Sg5                None preferred
# -46.00 -70.00 Tehuelche             Sg4                None preferred
# -39.00 -68.00 Mapuche               Sg2                   Uni: MoBrDa
#
# title                                      Cousin marriages preferred: subtypes  \
# Lat    Long   pref_name_for_society soc_id
# -55.02 -68.98 Yahgan                Sg1                          None preferred
# -54.00 -69.00 Ona                   Sg3                          None preferred
# -52.00 -74.00 Alacaluf              Sg5                          None preferred
# -46.00 -70.00 Tehuelche             Sg4                          None preferred
# -39.00 -68.00 Mapuche               Sg2                                  MoBrDa
#
# title                                           Domestic organization  \
# Lat    Long   pref_name_for_society soc_id
# -55.02 -68.98 Yahgan                Sg1     Nuclear, limited polygyny
# -54.00 -69.00 Ona                   Sg3     Nuclear, limited polygyny
# -52.00 -74.00 Alacaluf              Sg5     Nuclear, limited polygyny
# -46.00 -70.00 Tehuelche             Sg4                Small extended
# -39.00 -68.00 Mapuche               Sg2                Small extended
#
# title                                      Marital composition: monogamy and polygamy  \
# Lat    Long   pref_name_for_society soc_id
# -55.02 -68.98 Yahgan                Sg1                              Limited polygyny
# -54.00 -69.00 Ona                   Sg3                              Limited polygyny
# -52.00 -74.00 Alacaluf              Sg5                              Limited polygyny
# -46.00 -70.00 Tehuelche             Sg4                              Limited polygyny
# -39.00 -68.00 Mapuche               Sg2       Polygyny, non-sororal separate quarters
#
# title                                      Marital residence with kin: alternate  \
# Lat    Long   pref_name_for_society soc_id
# -55.02 -68.98 Yahgan                Sg1                             No alternate
# -54.00 -69.00 Ona                   Sg3                                 Neolocal
# -52.00 -74.00 Alacaluf              Sg5                                 Neolocal
# -46.00 -70.00 Tehuelche             Sg4                             No alternate
# -39.00 -68.00 Mapuche               Sg2                                 Neolocal
#
# title                                      Marital residence with kin: change after first years  \
# Lat    Long   pref_name_for_society soc_id
# -55.02 -68.98 Yahgan                Sg1                                                  Same
# -54.00 -69.00 Ona                   Sg3                                                  Same
# -52.00 -74.00 Alacaluf              Sg5                                             Different
# -46.00 -70.00 Tehuelche             Sg4                                                  Same
# -39.00 -68.00 Mapuche               Sg2                                                  Same
#
# title                                      Marital residence with kin: first years  \
# Lat    Long   pref_name_for_society soc_id
# -55.02 -68.98 Yahgan                Sg1                                  Virilocal
# -54.00 -69.00 Ona                   Sg3                                  Virilocal
# -52.00 -74.00 Alacaluf              Sg5                                 Uxorilocal
# -46.00 -70.00 Tehuelche             Sg4                                  Virilocal
# -39.00 -68.00 Mapuche               Sg2                                 Patrilocal
#
# title                                       ...  \
# Lat    Long   pref_name_for_society soc_id  ...
# -55.02 -68.98 Yahgan                Sg1     ...
# -54.00 -69.00 Ona                   Sg3     ...
# -52.00 -74.00 Alacaluf              Sg5     ...
# -46.00 -70.00 Tehuelche             Sg4     ...
# -39.00 -68.00 Mapuche               Sg2     ...
#
# title                                      Marital composition: monogamy and polygamy_numeric  \
# Lat    Long   pref_name_for_society soc_id
# -55.02 -68.98 Yahgan                Sg1                                                     0
# -54.00 -69.00 Ona                   Sg3                                                     0
# -52.00 -74.00 Alacaluf              Sg5                                                     0
# -46.00 -70.00 Tehuelche             Sg4                                                     0
# -39.00 -68.00 Mapuche               Sg2                                                     4
#
# title                                      Marital residence with kin: alternate_numeric  \
# Lat    Long   pref_name_for_society soc_id
# -55.02 -68.98 Yahgan                Sg1                                                6
# -54.00 -69.00 Ona                   Sg3                                                5
# -52.00 -74.00 Alacaluf              Sg5                                                5
# -46.00 -70.00 Tehuelche             Sg4                                                6
# -39.00 -68.00 Mapuche               Sg2                                                5
#
# title                                      Marital residence with kin: change after first years_numeric  \
# Lat    Long   pref_name_for_society soc_id
# -55.02 -68.98 Yahgan                Sg1                                                     1
# -54.00 -69.00 Ona                   Sg3                                                     1
# -52.00 -74.00 Alacaluf              Sg5                                                     0
# -46.00 -70.00 Tehuelche             Sg4                                                     1
# -39.00 -68.00 Mapuche               Sg2                                                     1
#
# title                                      Marital residence with kin: first years_numeric  \
# Lat    Long   pref_name_for_society soc_id
# -55.02 -68.98 Yahgan                Sg1                                                 11
# -54.00 -69.00 Ona                   Sg3                                                 11
# -52.00 -74.00 Alacaluf              Sg5                                                 10
# -46.00 -70.00 Tehuelche             Sg4                                                 11
# -39.00 -68.00 Mapuche               Sg2                                                  8
#
# title                                      Marital residence with kin: prevailing pattern_numeric  \
# Lat    Long   pref_name_for_society soc_id
# -55.02 -68.98 Yahgan                Sg1                                                    11
# -54.00 -69.00 Ona                   Sg3                                                    11
# -52.00 -74.00 Alacaluf              Sg5                                                     2
# -46.00 -70.00 Tehuelche             Sg4                                                    11
# -39.00 -68.00 Mapuche               Sg2                                                     8
#
# title                                      Organization of clan communities_numeric  \
# Lat    Long   pref_name_for_society soc_id
# -55.02 -68.98 Yahgan                Sg1                                           2
# -54.00 -69.00 Ona                   Sg3                                           2
# -52.00 -74.00 Alacaluf              Sg5                                           2
# -46.00 -70.00 Tehuelche             Sg4                                           2
# -39.00 -68.00 Mapuche               Sg2                                           2
#
# title                                       Transactions at marriage: alternate type_numeric  \
# Lat    Long   pref_name_for_society soc_id
# -55.02 -68.98 Yahgan                Sg1                                                    5
# -54.00 -69.00 Ona                   Sg3                                                    4
# -52.00 -74.00 Alacaluf              Sg5                                                    4
# -46.00 -70.00 Tehuelche             Sg4                                                    1
# -39.00 -68.00 Mapuche               Sg2                                                    4
#
# title                                       Transactions at marriage: prevailing type_numeric  \
# Lat    Long   pref_name_for_society soc_id
# -55.02 -68.98 Yahgan                Sg1                                                     0
# -54.00 -69.00 Ona                   Sg3                                                     4
# -52.00 -74.00 Alacaluf              Sg5                                                     4
# -46.00 -70.00 Tehuelche             Sg4                                                     3
# -39.00 -68.00 Mapuche               Sg2                                                     1
#
# title                                       Transfer of residence at marriage: alternate_numeric  \
# Lat    Long   pref_name_for_society soc_id
# -55.02 -68.98 Yahgan                Sg1                                                     2
# -54.00 -69.00 Ona                   Sg3                                                     0
# -52.00 -74.00 Alacaluf              Sg5                                                     2
# -46.00 -70.00 Tehuelche             Sg4                                                     2
# -39.00 -68.00 Mapuche               Sg2                                                     0
#
# title                                       Transfer of residence at marriage: prevailing pattern_numeric
# Lat    Long   pref_name_for_society soc_id
# -55.02 -68.98 Yahgan                Sg1                                                     3
# -54.00 -69.00 Ona                   Sg3                                                     3
# -52.00 -74.00 Alacaluf              Sg5                                                     0
# -46.00 -70.00 Tehuelche             Sg4                                                     3
# -39.00 -68.00 Mapuche               Sg2                                                     3
#
# [5 rows x 32 columns]

# %%
df_filtered_numeric = df_filtered.drop(columns=categorials)

# %%
df_filtered_numeric.head()
# Out:
# title                                       Community marriage organization_numeric  \
# Lat    Long   pref_name_for_society soc_id
# -55.02 -68.98 Yahgan                Sg1                                           3
# -54.00 -69.00 Ona                   Sg3                                           3
# -52.00 -74.00 Alacaluf              Sg5                                           0
# -46.00 -70.00 Tehuelche             Sg4                                           0
# -39.00 -68.00 Mapuche               Sg2                                           4
#
# title                                       Cousin marriages permitted_numeric  \
# Lat    Long   pref_name_for_society soc_id
# -55.02 -68.98 Yahgan                Sg1                                      5
# -54.00 -69.00 Ona                   Sg3                                      5
# -52.00 -74.00 Alacaluf              Sg5                                      0
# -46.00 -70.00 Tehuelche             Sg4                                      0
# -39.00 -68.00 Mapuche               Sg2                                      3
#
# title                                       Cousin marriages permitted: subtypes_numeric  \
# Lat    Long   pref_name_for_society soc_id
# -55.02 -68.98 Yahgan                Sg1                                                2
# -54.00 -69.00 Ona                   Sg3                                                2
# -52.00 -74.00 Alacaluf              Sg5                                                4
# -46.00 -70.00 Tehuelche             Sg4                                                4
# -39.00 -68.00 Mapuche               Sg2                                                7
#
# title                                       Cousin marriages preferred_numeric  \
# Lat    Long   pref_name_for_society soc_id
# -55.02 -68.98 Yahgan                Sg1                                      7
# -54.00 -69.00 Ona                   Sg3                                      7
# -52.00 -74.00 Alacaluf              Sg5                                      7
# -46.00 -70.00 Tehuelche             Sg4                                      7
# -39.00 -68.00 Mapuche               Sg2                                     14
#
# title                                       Cousin marriages preferred: subtypes_numeric  \
# Lat    Long   pref_name_for_society soc_id
# -55.02 -68.98 Yahgan                Sg1                                                4
# -54.00 -69.00 Ona                   Sg3                                                4
# -52.00 -74.00 Alacaluf              Sg5                                                4
# -46.00 -70.00 Tehuelche             Sg4                                                4
# -39.00 -68.00 Mapuche               Sg2                                                3
#
# title                                       Domestic organization_numeric  \
# Lat    Long   pref_name_for_society soc_id
# -55.02 -68.98 Yahgan                Sg1                                 2
# -54.00 -69.00 Ona                   Sg3                                 2
# -52.00 -74.00 Alacaluf              Sg5                                 2
# -46.00 -70.00 Tehuelche             Sg4                                 7
# -39.00 -68.00 Mapuche               Sg2                                 7
#
# title                                       Marital composition: monogamy and polygamy_numeric  \
# Lat    Long   pref_name_for_society soc_id
# -55.02 -68.98 Yahgan                Sg1                                                     0
# -54.00 -69.00 Ona                   Sg3                                                     0
# -52.00 -74.00 Alacaluf              Sg5                                                     0
# -46.00 -70.00 Tehuelche             Sg4                                                     0
# -39.00 -68.00 Mapuche               Sg2                                                     4
#
# title                                       Marital residence with kin: alternate_numeric  \
# Lat    Long   pref_name_for_society soc_id
# -55.02 -68.98 Yahgan                Sg1                                                 6
# -54.00 -69.00 Ona                   Sg3                                                 5
# -52.00 -74.00 Alacaluf              Sg5                                                 5
# -46.00 -70.00 Tehuelche             Sg4                                                 6
# -39.00 -68.00 Mapuche               Sg2                                                 5
#
# title                                       Marital residence with kin: change after first years_numeric  \
# Lat    Long   pref_name_for_society soc_id
# -55.02 -68.98 Yahgan                Sg1                                                     1
# -54.00 -69.00 Ona                   Sg3                                                     1
# -52.00 -74.00 Alacaluf              Sg5                                                     0
# -46.00 -70.00 Tehuelche             Sg4                                                     1
# -39.00 -68.00 Mapuche               Sg2                                                     1
#
# title                                       Marital residence with kin: first years_numeric  \
# Lat    Long   pref_name_for_society soc_id
# -55.02 -68.98 Yahgan                Sg1                                                  11
# -54.00 -69.00 Ona                   Sg3                                                  11
# -52.00 -74.00 Alacaluf              Sg5                                                  10
# -46.00 -70.00 Tehuelche             Sg4                                                  11
# -39.00 -68.00 Mapuche               Sg2                                                   8
#
# title                                       Marital residence with kin: prevailing pattern_numeric  \
# Lat    Long   pref_name_for_society soc_id
# -55.02 -68.98 Yahgan                Sg1                                                    11
# -54.00 -69.00 Ona                   Sg3                                                    11
# -52.00 -74.00 Alacaluf              Sg5                                                     2
# -46.00 -70.00 Tehuelche             Sg4                                                    11
# -39.00 -68.00 Mapuche               Sg2                                                     8
#
# title                                       Organization of clan communities_numeric  \
# Lat    Long   pref_name_for_society soc_id
# -55.02 -68.98 Yahgan                Sg1                                            2
# -54.00 -69.00 Ona                   Sg3                                            2
# -52.00 -74.00 Alacaluf              Sg5                                            2
# -46.00 -70.00 Tehuelche             Sg4                                            2
# -39.00 -68.00 Mapuche               Sg2                                            2
#
# title                                       Transactions at marriage: alternate type_numeric  \
# Lat    Long   pref_name_for_society soc_id
# -55.02 -68.98 Yahgan                Sg1                                                    5
# -54.00 -69.00 Ona                   Sg3                                                    4
# -52.00 -74.00 Alacaluf              Sg5                                                    4
# -46.00 -70.00 Tehuelche             Sg4                                                    1
# -39.00 -68.00 Mapuche               Sg2                                                    4
#
# title                                       Transactions at marriage: prevailing type_numeric  \
# Lat    Long   pref_name_for_society soc_id
# -55.02 -68.98 Yahgan                Sg1                                                     0
# -54.00 -69.00 Ona                   Sg3                                                     4
# -52.00 -74.00 Alacaluf              Sg5                                                     4
# -46.00 -70.00 Tehuelche             Sg4                                                     3
# -39.00 -68.00 Mapuche               Sg2                                                     1
#
# title                                       Transfer of residence at marriage: alternate_numeric  \
# Lat    Long   pref_name_for_society soc_id
# -55.02 -68.98 Yahgan                Sg1                                                     2
# -54.00 -69.00 Ona                   Sg3                                                     0
# -52.00 -74.00 Alacaluf              Sg5                                                     2
# -46.00 -70.00 Tehuelche             Sg4                                                     2
# -39.00 -68.00 Mapuche               Sg2                                                     0
#
# title                                       Transfer of residence at marriage: prevailing pattern_numeric
# Lat    Long   pref_name_for_society soc_id
# -55.02 -68.98 Yahgan                Sg1                                                     3
# -54.00 -69.00 Ona                   Sg3                                                     3
# -52.00 -74.00 Alacaluf              Sg5                                                     0
# -46.00 -70.00 Tehuelche             Sg4                                                     3
# -39.00 -68.00 Mapuche               Sg2                                                     3

# %% [markdown]
# ## 3. Exploratory data analysis

# %% [markdown]
# ### 3.1 Korrelációs mátrix készítése

# %% [markdown]
# Felfedezzük az adatot. Első lépésként megnézzük, hogy a vizsgálatba bevont 16 változó mennyire korrelál egymással.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'df' is your DataFrame
plt.figure(figsize=(15, 10))

# Using Seaborn to create a heatmap
sns.heatmap(df_filtered_numeric.corr(), annot=True, fmt='.2f', cmap='Pastel2', linewidths=2)

plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Láthatjuk, hogy nincsenek magasan korreláló változók, mindegyik 0,85 alatti. Ahol 0,65-0,75 közötti az érték, nem meglepő, mert ezek az értékek egymás alesetei. Pl.cousin marriage preferred és cousin marriage preferred: subtypes korrelációja 0,65

# %% [markdown]
# ### 3.2 Scatterplot készítése

# %% [markdown]
# Második lépésként két dimenziós vektorokat csinálunk a 16 feature-ből/változóból és 2D-ben ábrázoljuk őket. Arra vagyunk kíváncsiak, vannak-e csoportosulások.

# %%
import umap

reducer = umap.UMAP()
embedding = reducer.fit_transform(df_filtered_numeric)
embedding.shape
# Out:
# (914, 2)

# %%
df_final = df_filtered_numeric.reset_index()

# %%
xs = [e[0] for e in embedding]
ys = [e[1] for e in embedding]
df_filtered_numeric["x"] = xs
df_filtered_numeric["y"] = ys

# %%
data_dict = {"xs": xs,
            "ys": ys,
            "ts": df_final["pref_name_for_society"]}

# %%
dd = pd.DataFrame(data_dict)
dd.head()
# Out:
#           xs         ys         ts
# 0  12.006637  -0.739520     Yahgan
# 1  12.344110  -0.938999        Ona
# 2  15.963363   1.563935   Alacaluf
# 3  14.218405   5.500136  Tehuelche
# 4  16.304543  12.308971    Mapuche

# %%
import altair as alt

alt.Chart(dd).mark_circle(size=60).encode(
    x='xs:Q',
    y='ys:Q',
    tooltip='ts',
).properties(width=800, height=800).interactive()
# Out:
# alt.Chart(...)

# %% [markdown]
# 3 jól elkülöníthető csoportot fedezhetünk fel és néhány outlier-t, ami elég ígéretes a klaszterelemzést illetően.

# %% [markdown]
# ### 3.3 Térkép készítése

# %% [markdown]
# Harmadik lépésként megnézzük, földrajzilag mennyire változatos a vizsgált kultúrák/társadalmak.

# %% [markdown]
# Mivel eddig nem dolgoztunk az éghajlat adatokkal, ezért készítünk egy olyan adatbázist, ahol ezt is összegyúrjuk az eddig használt adatbázissal, majd térkpépre tesszük a társadalmakat.

# %%
df_all_features = pd.merge(df_final,climate_final, on=["soc_id"])
df_all_features.head()
# Out:
#      Lat   Long pref_name_for_society soc_id  \
# 0 -55.02 -68.98                Yahgan    Sg1
# 1 -54.00 -69.00                   Ona    Sg3
# 2 -52.00 -74.00              Alacaluf    Sg5
# 3 -46.00 -70.00             Tehuelche    Sg4
# 4 -39.00 -68.00               Mapuche    Sg2
#
#    Community marriage organization_numeric  \
# 0                                        3
# 1                                        3
# 2                                        0
# 3                                        0
# 4                                        4
#
#    Cousin marriages permitted_numeric  \
# 0                                   5
# 1                                   5
# 2                                   0
# 3                                   0
# 4                                   3
#
#    Cousin marriages permitted: subtypes_numeric  \
# 0                                             2
# 1                                             2
# 2                                             4
# 3                                             4
# 4                                             7
#
#    Cousin marriages preferred_numeric  \
# 0                                   7
# 1                                   7
# 2                                   7
# 3                                   7
# 4                                  14
#
#    Cousin marriages preferred: subtypes_numeric  \
# 0                                             4
# 1                                             4
# 2                                             4
# 3                                             4
# 4                                             3
#
#    Domestic organization_numeric  ...  \
# 0                              2  ...
# 1                              2  ...
# 2                              2  ...
# 3                              7  ...
# 4                              7  ...
#
#    Marital residence with kin: change after first years_numeric  \
# 0                                                  1
# 1                                                  1
# 2                                                  0
# 3                                                  1
# 4                                                  1
#
#    Marital residence with kin: first years_numeric  \
# 0                                               11
# 1                                               11
# 2                                               10
# 3                                               11
# 4                                                8
#
#    Marital residence with kin: prevailing pattern_numeric  \
# 0                                                 11
# 1                                                 11
# 2                                                  2
# 3                                                 11
# 4                                                  8
#
#    Organization of clan communities_numeric  \
# 0                                         2
# 1                                         2
# 2                                         2
# 3                                         2
# 4                                         2
#
#    Transactions at marriage: alternate type_numeric  \
# 0                                                 5
# 1                                                 4
# 2                                                 4
# 3                                                 1
# 4                                                 4
#
#    Transactions at marriage: prevailing type_numeric  \
# 0                                                  0
# 1                                                  4
# 2                                                  4
# 3                                                  3
# 4                                                  1
#
#    Transfer of residence at marriage: alternate_numeric  \
# 0                                                  2
# 1                                                  0
# 2                                                  2
# 3                                                  2
# 4                                                  0
#
#    Transfer of residence at marriage: prevailing pattern_numeric  \
# 0                                                  3
# 1                                                  3
# 2                                                  0
# 3                                                  3
# 4                                                  3
#
#    AnnualMeanTemperature  MonthlyMeanPrecipitation
# 0               4.040226              106173.97620
# 1               3.673221               99406.99295
# 2               5.833743              135790.88890
# 3               5.156873               51252.80265
# 4              10.339714               41571.08374
#
# [5 rows x 22 columns]

# %%
import altair as alt
import pandas as pd
from vega_datasets import data

source = alt.topo_feature(data.world_110m.url, 'countries')
background = alt.Chart(source).mark_geoshape(
    fill='lightgray',
    stroke='white'
    ).properties(
    width=700,
    height=600
)
points = alt.Chart(df_all_features).mark_circle().encode(
    longitude='Long',
    latitude='Lat',
    size=alt.value(50),
    color=alt.Color().title("Az elemzésbe bevont társadalmak"),
    tooltip="pref_name_for_society",
).properties().interactive()

chart = background + points
chart
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ## 4. Adatok lementése csv-be

# %%
dd.to_csv('../data/twodimensions.csv', index=False)

# %%
df_all_features.to_csv('../data/numeric.csv', index=False)

# %% [markdown]
# ## Hivatkozások

# %% [markdown]
# Fox, R. (1998). Kinship and marriage : an anthropological perspective. Cambridge University Press.
# Hendry, J. (1999). Family, Kinship and Marriage. In: An Introduction to Social Anthropology. Palgrave, London. https://doi.org/10.1007/978-1-349-27281-5_12
# Itao, K., & Kaneko, K. (2020). Evolution of kinship structures driven by marriage tie and competition. Proceedings of the National Academy of Sciences of the United States of America, 117(5), 2378–2384. https://doi.org/10.1073/pnas.1917716117
# Lima-Ribeiro et al. (2015). 'ecoClimate' (v3.0) [Data set]. Zenodo. https://doi.org/10.5281/zenodo.10179301
# Murdock et al. (1999). 'Ethnographic Atlas' (v3.0) [Data set]. Zenodo. https://doi.org/10.5281/zenodo.10177061
# Ophir, A. G., & Solomon, N. G. (2020). What’s Love Got to Do with it: The Evolution of Monogamy. Frontiers Media SA.
# Parker, S. (1996). Full Brother-Sister Marriage in Roman Egypt: Another Look. Cultural Anthropology, 11(3), 362–376. https://doi.org/10.1525/can.1996.11.3.02a00040
